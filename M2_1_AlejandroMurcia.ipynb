# %% [markdown]
# <a href="https://colab.research.google.com/github/alejandrxmurcia/ActividadFormativaM2-Equipo3/blob/main/M2_1_AlejandroMurcia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # "Actividad M2.1 Uso de Google Colab"

# %% [markdown]
# ### **Nombre:** Alejandro Murcia
# ### **Matricula:** A00828513

# %% [markdown]
# ### Lectura de Datos

# %%
#Import pandas library
import pandas as pd

# %%
#Give access to out Google Drive path
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Load the CSV to a dataframe
df = pd.read_csv('/content/gdrive/MyDrive/TC2004B/titanic.csv')

# %%
#Verify the data was successfully loaded to the data frame. First, we show the head of the df.
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#We show the tail of the df
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### Descripción de Variables

# %%
#We describe the type of data from each column 
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# *   PassengerId: Categorica
# *   Survived: Categorica
# *   PClass: Categorica
# *   Name: Categorica
# *   Sex: Categorica
# *   Age: Numerica
# *   SibSp: Categorica
# *   Parch: Numerica
# *   Ticket: Categorica
# *   Fare: Numerica
# *   Cabin: Categorica
# *   Embarked: Categorica

# %%
#Use of columns(). We see the header of each column separated by a comma, this data structure is an object.
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Use of info(). We see each column with its header, data type, and the count of non-null values that it has. Also, classifies each column according to its data type.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Use of describe(). Displays a statistical summary of every column, including mean, standard deviation, minimum and maximum value, and also the quartiles. 
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Showing the total number of rows or registers that our data frame has.

print('El numero de pasajeros es:', len(df))
# Out:
# El numero de pasajeros es: 891

# %%
# We display the number of null values in each column.
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#We display the number of not null values in each column.
df.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
# What columns are displayed in the describe() function?

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Todas las columnas son desplegadas. Asi mismo, de cada una de ellas se realiza un resumen estadistico que incluye la media, desviacion estandar, minimo, maximo y los cuartiles.

# %%
# What is the most expensive fare?

print('The most expensive fare was: $', df['Fare'].max())
# Out:
# The most expensive fare was: $ 512.3292

# %%
# What is the average age?
print('The average age? was:', df['Age'].mean())
# Out:
# The average age? was: 29.69911764705882

# %%
#Categorical Variables

print('Survived', df['Survived'].unique())
print('Pclass', df['Pclass'].unique())
print('Sex', df['Sex'].unique())
print('SibSp', df['SibSp'].unique())
print('Ticket', df['Ticket'].unique())
print('Cabin', df['Cabin'].unique())
print('Embarked', df['Embarked'].unique())
# Out:
# Survived [0 1]
# Pclass [3 1 2]
# Sex ['male' 'female']
# SibSp [1 0 3 4 2 5 8]
# Ticket ['A/5 21171' 'PC 17599' 'STON/O2. 3101282' '113803' '373450' '330877'
#  '17463' '349909' '347742' '237736' 'PP 9549' '113783' 'A/5. 2151'
#  '347082' '350406' '248706' '382652' '244373' '345763' '2649' '239865'
#  '248698' '330923' '113788' '347077' '2631' '19950' '330959' '349216'
#  'PC 17601' 'PC 17569' '335677' 'C.A. 24579' 'PC 17604' '113789' '2677'
#  'A./5. 2152' '345764' '2651' '7546' '11668' '349253' 'SC/Paris 2123'
#  '330958' 'S.C./A.4. 23567' '370371' '14311' '2662' '349237' '3101295'
#  'A/4. 39886' 'PC 17572' '2926' '113509' '19947' 'C.A. 31026' '2697'
#  'C.A. 34651' 'CA 2144' '2669' '113572' '36973' '347088' 'PC 17605' '2661'
#  'C.A. 29395' 'S.P. 3464' '3101281' '315151' 'C.A. 33111' 'S.O.C. 14879'
#  '2680' '1601' '348123' '349208' '374746' '248738' '364516' '345767'
#  '345779' '330932' '113059' 'SO/C 14885' '3101278' 'W./C. 6608'
# ...

# %% [markdown]
# ### Análisis de Datos

# %%
print('Total payed by the passangers: $', df['Fare'].sum())
# Out:
# Total payed by the passangers: $ 28693.9493

# %%
#Create a df with the passengers who survived
df_sur = df[df["Survived"] == 1]
df_sur.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
#Create a df with the passengers who didn't survive
df_not_sur = df[df["Survived"] == 0]
df_not_sur.head(5)
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4            5         0       3        Allen, Mr. William Henry  male  35.0
# 5            6         0       3                Moran, Mr. James  male   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S
